# %% [markdown]
# # **Procura de Problemas Éticos em Issues**

# %%
#%pip install pandas
#%pip install nltk
#%pip install ipywidgets


import pandas as pd
import os
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

# %% [markdown]
# # **Implementando palavras éticas obtidas em txt**

# %%
with open("IET-Software-2023-Biable-Proposed-ethical-framework-for-software-requirements-engineering.txt", "r", encoding="utf-8") as arquivo:
    texto = arquivo.read()
    
texto = texto.lower()
texto
# Out:
# 'received: 24 september 2022\n\ndoi: 10.1049/sfw2.12136\n\n\noriginal research\n                               - -\n                                 revised: 19 may 2023      accepted: 27 june 2023\n\n\n                                                                                                                                                      -   iet software\n\n\n\n\nproposed ethical framework for software requirements\nengineering\n\nseblewongel e. biable1                             | nuno m. garcia2,3                          | dida midekso4\n\n1\naddis ababa university, addis ababa, ethiopia           abstract\n2\n faculdade de ciências, universidade de lisboa,         requirements engineering is a fundamental process in software development phases. at\nlisbon, portugal                                        the same time, it is a difficult phase and exposed many ethical violations. the main\n3\ninstituto de telecomunicações, covilhã, portugal        purpose is proposing an ethical framework for software requirements engineering that\n4\ndepartment of computer science, addis ababa             addresses the identified concerns. these concerns include problems associated with a\nuniversity, addis ababa, ethiopia                       knowledge gap, requirements identification, quality‐related concerns, unwillingness to\n                                                        give requirements, and practicing forbidden activities. these concerns are grouped into a\ncorrespondence\n                                                        category as the proposed framework components. each of the categories encompasses\nseblewongel e. biable.\nemail: sebess2011@gmail.com\n                                                        more than one problem domain. the proposed framework suggests resolving mecha-\n                                                        nisms as collections of clauses for each of those concerns. an expert evaluation technique\nnuno m. garcia.\nemail: nmgarcia@fc.ul.pt                                is used to validate the proposed framework. the experts are purposefully selected from\n                                                        software industries and institutions. questionnaires and focus group discussions were\nfunding information                                     used as data‐gathering tools for the validation of the proposed framework. the validity\nfct/mec; feder—pt2020                                   (face validity, content validity, and construct validity) and the reliability of the proposed\n                                                        framework were checked. the evaluation results show that the proposed framework has\n                                                        an acceptable range of validity and reliability. the proposed framework can be used as a\n                                                        guideline for software engineers to minimise the occurrence of those identified concerns\n                                                        during the requirements engineering process.\n\n                                                        keywords\n                                                        data privacy, data protection, human factors, software development management, software engineering\n\n\n\n1 | introduction                                                                           often, these malfunctioning effects are caused by software\n                                                                                           engineers\' negligence by disregarding their professional obli-\n1.1 | motivation and statement of the                                                      gations and engaging in unethical professional behaviour [2, 4].\nproblem                                                                                    developing software systems without clearly considering\n                               ...

# %%
# Definindo as StopWords
nltk.download('stopwords')
stopWords = set(stopwords.words('english'))

def removerStopWords(palavras):
    return [palavra for palavra in palavras if palavra not in stopWords and palavra.isalpha()]

# Criando um tokenizer que considera expressões
expressoes = {'influence factors', 'knowledge gap', 'non-maleficence', 'professional Behaviour', 'professional codes', 'requirements engineering', 'requirements identification',
              'requirements quality', 'working environment'}

expressaoRegular = r'\b(?:' + '|'.join(expressoes) + r')\b|\w+'
tokenizer = RegexpTokenizer(expressaoRegular)


# Tokenize dos comentarios das issues

textoToK = tokenizer.tokenize(texto)
textoToK = removerStopWords(textoToK)

textoToK
# Out:
# [nltk_data] Downloading package stopwords to /home/zoega/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['received',
#  'september',
#  'doi',
#  'original',
#  'research',
#  'revised',
#  'may',
#  'accepted',
#  'june',
#  'iet',
#  'software',
#  'proposed',
#  'ethical',
#  'framework',
#  'software',
#  'requirements',
#  'engineering',
#  'seblewongel',
#  'e',
#  'nuno',
#  'dida',
#  'addis',
#  'ababa',
#  'university',
#  'addis',
#  'ababa',
#  'ethiopia',
#  'abstract',
#  'faculdade',
#  'de',
#  'ciências',
#  'universidade',
#  'de',
#  'lisboa',
#  'fundamental',
#  'process',
#  'software',
#  'development',
#  'phases',
#  'lisbon',
#  'portugal',
#  'time',
#  'difficult',
#  'phase',
#  'exposed',
#  'many',
#  'ethical',
#  'violations',
#  'main',
#  'instituto',
#  'de',
#  'telecomunicações',
#  'covilhã',
#  'portugal',
#  'purpose',
#  'proposing',
#  'ethical',
#  'framework',
#  'software',
#  'department',
#  'computer',
#  'science',
#  'addis',
#  'ababa',
#  'addresses',
#  'identified',
#  'concerns',
#  'concerns',
#  'include',
#  'problems',
#  'associated',
#  'university',
#  'addis',
#  'ababa',
#  'ethiopia',
#  'quality',
#  'related',
#  'concerns',
#  'unwillingness',
#  'give',
#  'requirements',
#  'practicing',
#  'forbidden',
#  'activities',
#  'concerns',
#  'grouped',
#  'correspondence',
#  'category',
#  'proposed',
#  'framework',
#  'components',
#  'categories',
#  'encompasses',
#  'seblewongel',
#  'e',
#  'biable',
#  'email',
#  'gmail',
#  'com',
#  'one',
#  'problem',
#  'domain',
#  'proposed',
#  'framework',
#  'suggests',
#  'resolving',
#  'mecha',
#  'nisms',
#  'collections',
#  'clauses',
#  'concerns',
#  'expert',
#  'evaluation',
#  'technique',
#  'nuno',
#  'garcia',
#  'email',
#  'nmgarcia',
#  'fc',
#  'ul',
#  'pt',
#  'used',
#  'validate',
#  'proposed',
#  'framework',
#  'experts',
#  'purposefully',
#  'selected',
#  'software',
#  'industries',
#  'institutions',
#  'questionnaires',
#  'focus',
#  'group',
#  'discussions',
#  'funding',
#  'information',
#  'used',
#  'data',
#  'gathering',
#  'tools',
#  'validation',
#  'proposed',
#  'framework',
#  'validity',
#  'fct',
#  'mec',
#  'feder',
#  'face',
#  'validity',
#  'content',
#  'validity',
#  'construct',
#  'validity',
#  'reliability',
#  'proposed',
#  'framework',
#  'checked',
#  'evaluation',
#  'results',
#  'show',
#  'proposed',
#  'framework',
#  'acceptable',
#  'range',
#  'validity',
#  'reliability',
#  'proposed',
#  'framework',
#  'used',
#  'guideline',
#  'software',
#  'engineers',
#  'minimise',
#  'occurrence',
#  'identified',
#  'concerns',
#  'process',
#  'keywords',
#  'data',
#  'privacy',
#  'data',
#  'protection',
#  'human',
#  'factors',
#  'software',
#  'development',
#  'management',
#  'software',
#  'engineering',
#  'introduction',
#  'often',
#  'malfunctioning',
#  'effects',
#  'caused',
#  'software',
#  'engineers',
#  'negligence',
#  'disregarding',
#  'professional',
#  'obli',
#  'motivation',
#  'statement',
#  'gations',
#  'engaging',
#  'unethical',
#  'professional',
#  'behaviour',
#  'problem',
#  'developing',
#  'software',
#  'systems',
#  'without',
#  'clearly',
#  'considering',
#  'ethical',
#  'values',
#  'may',
#  'lead',
#  'development',
#  'software',
#  'arte',
#  'software',
#  'abasic',
#  'component',
#  'computer',
#  'system',
#  'de',
#  'facts',
#  'could',
#  'fulfil',
#  'societal',
#  'values',
#  'may',
#  'cause',
#  'damage',
#  'termines',
#  'values',
#  'artefacts',
#  'accordingly',
#  'software',
#  'public',
#  'large',
#  'due',
#  'lack',
#  'awareness',
#  'related',
#  'problems',
#  'negative',
#  'impacts',
#  'stakeholders',
#  'individuals',
#  'areas',
#  'ethical',
#  'concerns',
#  'conundrums',
#  'many',
#  'cases',
#  'origin',
#  'numerous',
#  'technological',
#  'fail',
#  'difficult',
#  'identify',
#  'advance',
#  'ethical',
#  'concerns',
#  'chal',
#  'ures',
#  'comes',
#  'software',
#  'related',
#  'concerns',
#  'failure',
#  'lenging',
#  'field',
#  'software',
#  'engineering',
#  'software',
#  'systems',
#  'negatively',
#  'affect',
#  'livelihoods',
#  'incorporating',
#  'ethical',
#  'dividuals',
#  'disastrous',
#  'consequences',
#  'public',
#  'values',
#  'software',
#  'requirements',
#  'help',
#  'identify',
#  'toxic',
#  'even',
#  'though',
#  'failure',
#  'malfunction',
#  'software',
#  'systems',
#  'deceptive',
#  'incomplete',
#  'unnecessary',
#  'inclined',
#  'project',
#  'management',
#  'issues',
#  'also',
#  'related',
#  'quirements',
#  'turn',
#  'helps',
#  'minimise',
#  'negative',
#  'im',
#  'human',
#  'factors',
#  'clients',
#  'stakeholders',
#  'pacts',
#  'software',
#  'artefacts',
#  'stakeholders',
#  'well',
#  'open',
#  'access',
#  'article',
#  'terms',
#  'creative',
#  'commons',
#  'attribution',
#  'noncommercial',
#  'noderivs',
#  'license',
#  'permits',
#  'use',
#  'distribution',
#  'medium',
#  'provided',
#  'original',
#  'work',
#  'properly',
#  'cited',
#  'use',
#  'non',
#  'commercial',
#  'modifications',
#  'adaptations',
#  'made',
#  'authors',
#  'iet',
#  'software',
#  'published',
#  'john',
#  'wiley',
#  'sons',
#  'ltd',
#  'iet',
#  'soft',
#  'wileyonlinelibrary',
#  'com',
#  'journal',
#  'downloaded',
#  'https',
#  'ietresearch',
#  'onlinelibrary',
#  'wiley',
#  'com',
#  'doi',
#  'capes',
#  'wiley',
#  'online',
#  'library',
#  'see',
#  'terms',
#  'conditions',
#  'https',
#  'onlinelibrary',
#  'wiley',
#  'com',
#  'terms',
#  'conditions',
#  'wiley',
#  'online',
#  'library',
#  'rules',
#  'use',
#  'oa',
#  'articles',
#  'governed',
#  'applicable',
#  'creative',
#  'commons',
#  'license',
#  'biable',
#  'et',
#  'al',
#  'public',
#  'success',
#  'software',
#  'development',
#  'projects',
#  'research',
#  'revealed',
#  'company',
#  'wide',
#  'enhanced',
#  'policies',
#  'professional',
#  'responsibility',
#  'code',
#  'conduct',
#  'stan',
#  'best',
#  'knowledge',
#  'researchers',
#  'research',
#  'dards',
#  'standards',
#  'integrating',
#  'ethical',
#  'considerations',
#  'found',
#  'integrates',
#  'ethical',
#  'values',
#  'requirements',
#  'en',
#  'software',
#  'requirements',
#  'course',
#  'requirements',
#  'engi',
#  'gineering',
#  'phase',
#  'software',
#  'development',
#  'project',
#  'therefore',
#  'neering',
#  'processes',
#  'research',
#  'also',
#  'showed',
#  'software',
#  'motivation',
#  'research',
#  'initiated',
#  'researchers',
#  'industries',
#  'lack',
#  'methods',
#  'determining',
#  'whether',
#  'ethical',
#  'con',
#  'propose',
#  'framework',
#  'ethics',
#  'siderations',
#  'taken',
#  'account',
#  'addresses',
#  'basic',
#  'concerns',
#  'identified',
#  'biable',
#  'et',
#  'al',
#  'five',
#  'themes',
#  'identified',
#  'qualitative',
#  'data',
#  'analysis',
#  'biable',
#  'et',
#  'al',
#  'according',
#  'researchers',
#  'fundamental',
#  'ethical',
#  'concerns',
#  'theme',
#  'whose',
#  'categories',
#  'research',
#  'methodology',
#  'include',
#  'problems',
#  'quality',
#  'related',
#  'problems',
#  'performing',
#  'forbidden',
#  'activities',
#  'unwillingness',
#  'research',
#  'aimed',
#  'developing',
#  'framework',
#  'helps',
#  'give',
#  'requirements',
#  'knowledge',
#  'gaps',
#  'needs',
#  'addressed',
#  'solve',
#  'ethical',
#  'concerns',
#  'identi',
#  'developing',
#  'ethical',
#  'framework',
#  'therefore',
#  'main',
#  'fied',
#  'five',
#  'major',
#  'themes',
#  'identified',
#  'purpose',
#  'paper',
#  'propose',
#  'ethical',
#  'framework',
#  'qualitative',
#  'data',
#  'analysis',
#  'biable',
#  'et',
#  'al',
#  'used',
#  'base',
#  'addresses',
#  'problems',
#  'identified',
#  'fundamental',
#  'proposed',
#  'framework',
#  'discussed',
#  'paper',
#  'ethical',
#  'concerns',
#  'theme',
#  'proposed',
#  'framework',
#  'evaluated',
#  'using',
#  'expert',
#  'judgement',
#  'experts',
#  'selected',
#  'purposefully',
#  'software',
#  'industries',
#  'institutes',
#  'focus',
#  'group',
#  'discus',
#  'literature',
#  'review',
#  'sions',
#  'questionnaires',
#  'used',
#  'evaluation',
#  'proposed',
#  'framework',
#  'frameworks',
#  'requirements',
#  'engineering',
#  'contribution',
#  'proposed',
#  'different',
#  'scholars',
#  'define',
#  'frameworks',
#  'different',
#  'ways',
#  'framework',
#  'cambridge',
#  'dictionary',
#  'defines',
#  'framework',
#  'supporting',
#  'structure',
#  'around',
#  'something',
#  'built',
#  'system',
#  'main',
#  'contribution',
#  'research',
#  'proposed',
#  'rules',
#  'ideas',
#  'beliefs',
#  'used',
#  'plan',
#  'decide',
#  'quirements',
#  'engineering',
#  'ethical',
#  'framework',
#  'proposed',
#  'thing',
#  'structure',
#  'around',
#  'something',
#  'built',
#  'framework',
#  'primarily',
#  'serve',
#  'practical',
#  'guideline',
#  'ideas',
#  'information',
#  'principles',
#  'form',
#  'structure',
#  'software',
#  'engineers',
#  'daily',
#  'basis',
#  'moreover',
#  'proposed',
#  'organisation',
#  'plan',
#  'framework',
#  'potential',
#  'used',
#  'future',
#  'research',
#  'similarly',
#  'oxford',
#  'dictionary',
#  'defines',
#  'framework',
#  'input',
#  'investigate',
#  'ethical',
#  'concerns',
#  'set',
#  'beliefs',
#  'ideas',
#  'rules',
#  'used',
#  'basis',
#  'remaining',
#  'system',
#  'development',
#  'life',
#  'cycles',
#  'making',
#  'judgements',
#  'decisions',
#  'etc',
#  'structure',
#  'particular',
#  'system',
#  'basic',
#  'framework',
#  'society',
#  'regulatory',
#  'legislative',
#  'framework',
#  'framework',
#  'background',
#  'mething',
#  'way',
#  'medical',
#  'dictionary',
#  'defines',
#  'several',
#  'applications',
#  'ethics',
#  'various',
#  'contexts',
#  'framework',
#  'basic',
#  'structure',
#  'something',
#  'fields',
#  'study',
#  'similar',
#  'academic',
#  'disciplines',
#  'ethics',
#  'formulated',
#  'built',
#  'substantial',
#  'influence',
#  'choices',
#  'made',
#  'computing',
#  'software',
#  'engineering',
#  'different',
#  'definitions',
#  'creation',
#  'software',
#  'objects',
#  'procedures',
#  'result',
#  'framework',
#  'popularly',
#  'field',
#  'framework',
#  'becomes',
#  'essential',
#  'take',
#  'ethics',
#  'account',
#  'defined',
#  'platform',
#  'helps',
#  'software',
#  'engineers',
#  'quirements',
#  'engineering',
#  'done',
#  'software',
#  'develop',
#  'develop',
#  'software',
#  'programs',
#  'systems',
#  'related',
#  'arte',
#  'ment',
#  'process',
#  'biable',
#  'et',
#  'al',
#  'investigated',
#  'requirements',
#  'facts',
#  'engineering',
#  'ethical',
#  'concerns',
#  'real',
#  'various',
#  'types',
#  'frameworks',
#  'different',
#  'fields',
#  'software',
#  'industries',
#  'researchers',
#  'employed',
#  'interviews',
#  'study',
#  'instance',
#  'take',
#  'engineering',
#  'medical',
#  'field',
#  'focus',
#  'group',
#  'discussions',
#  'data',
#  'gathering',
#  'tools',
#  'examine',
#  'study',
#  'many',
#  'frameworks',
#  'designed',
#  'seven',
#  'software',
#  'industries',
#  'various',
#  'sizes',
#  'small',
#  'medium',
#  'different',
#  'purposes',
#  'field',
#  'requirements',
#  'engi',
#  'large',
#  'maturity',
#  'levels',
#  'various',
#  'years',
#  'experience',
#  'neering',
#  'scholars',
#  'proposed',
#  'frameworks',
#  'different',
#  'purposive',
#  'sampling',
#  'approaches',
#  'utilised',
#  'choose',
#  'purposes',
#  'example',
#  'indicate',
#  'companies',
#  'specific',
#  'individuals',
#  'company',
#  'willing',
#  'schon',
#  'et',
#  'al',
#  'proposed',
#  'framework',
#  'improving',
#  'agile',
#  'companies',
#  'intensively',
#  'engaged',
#  'developing',
#  'software',
#  'arayici',
#  'et',
#  'al',
#  'developed',
#  'artefacts',
#  'products',
#  'selected',
#  'qualitative',
#  'data',
#  'requirement',
#  'engineering',
#  'framework',
#  'purpose',
#  'inte',
#  'analysis',
#  'methods',
#  'holistic',
#  'coding',
#  'initial',
#  'coding',
#  'vivo',
#  'grated',
#  'system',
#  'development',
#  'construction',
#  'industry',
#  'coding',
#  'attribute',
#  'coding',
#  'procedures',
#  'employed',
#  'kabaale',
#  'kituyi',
#  'proposed',
#  'examine',
#  'gathered',
#  'data',
#  'framework',
#  'process',
#  'improvements',
#  'small',
#  'medium',
#  'downloaded',
#  'https',
#  'ietresearch',
#  'onlinelibrary',
#  'wiley',
#  'com',
#  'doi',
#  'capes',
#  'wiley',
#  'online',
#  'library',
#  'see',
#  'terms',
#  'conditions',
#  'https',
#  'onlinelibrary',
#  'wiley',
#  'com',
#  'terms',
#  'conditions',
#  'wiley',
#  'online',
#  'library',
#  'rules',
#  'use',
#  'oa',
#  'articles',
#  'governed',
#  'applicable',
#  'creative',
#  'commons',
#  'license',
#  'biable',
#  'et',
#  'al',
#  'software',
#  'companies',
#  'gupta',
#  'aziz',
#  'proposed',
#  'software',
#  'development',
#  'methodologies',
#  'study',
#  'identified',
#  'requirements',
#  'ambiguity',
#  'avoidance',
#  'framework',
#  'help',
#  'many',
#  'challenges',
#  'quirements',
#  'engineers',
#  'write',
#  'unambiguous',
#  'complete',
#  'correct',
#  'search',
#  'widely',
#  'occurring',
#  'challenges',
#  'problems',
#  'proper',
#  'accurate',
#  'requirements',
#  'bates',
#  'developed',
#  'include',
#  'security',
#  'related',
#  'problems',
#  'lack',
#  'integrated',
#  'models',
#  'ethical',
#  'framework',
#  'engineering',
#  'professionals',
#  'students',
#  'frameworks',
#  'processes',
#  'address',
#  'ethics',
#  'two',
#  'perspectives',
#  'first',
#  'perspective',
#  'quality',
#  'related',
#  'problems',
#  'due',
#  'insufficient',
#  'requirements',
#  'en',
#  'enhance',
#  'knowledge',
#  'engineering',
#  'graduates',
#  'regarding',
#  'gineering',
#  'processes',
#  'missing',
#  'requirements',
#  'giving',
#  'less',
#  'attention',
#  'professional',
#  'ethical',
#  'responsibilities',
#  'second',
#  'non',
#  'functional',
#  'requirements',
#  'aberkane',
#  'et',
#  'al',
#  'assist',
#  'practitioners',
#  'face',
#  'different',
#  'kinds',
#  'ethical',
#  'problems',
#  'carried',
#  'systematic',
#  'grey',
#  'literature',
#  'reviews',
#  'concerning',
#  'challenges',
#  'protect',
#  'engaging',
#  'unethical',
#  'ethical',
#  'issues',
#  'ramingwong',
#  'activities',
#  'framework',
#  'used',
#  ...]

# %%
PalavrasEticas = [
    "autonomy",
    "beneficence",
    "bias",
    "business",
    "choices",
    "considerations",
    "deceptive",
    "dignity",
    "exposed",
    "fairness",
    "factors",
    "forbidden",
    "framework",
    "freedom",
    "governance",
    "guidelines",
    "harm",
    "identification",
    "importance",
    "influence",
    "influence factors",
    "issues",
    "justice",
    "knowledge",
    "knowledge gap",
    "lack",
    "legal",
    "management",
    "negligence",
    "non-maleficence",
    "norms",
    "obligation",
    "operation",
    "perspective",
    "practices",
    "principle",
    "privacy",
    "problems",
    "professional Behaviour",
    "professional codes",
    "profit",
    "quality",
    "relevance",
    "requirements",
    "requirements engineering",
    "requirements identification",
    "requirements quality",
    "responsible",
    "responsibility",
    "risk",
    "rules",
    "side",
    "skill",
    "solidarity",
    "stage",
    "standard",
    "sustainability",
    "technical",
    "tool",
    "toxic",
    "transparency",
    "trustworthy",
    "unpermitted",
    "values",
    "violation",
    "viability",
    "visibility",
    "washing",
    "working environment"
]

# Criando o DataFrame que guardará as ocorrências dos comentários
ocorrenciasArtigo = pd.DataFrame()
linhaInicial = 0 * len(PalavrasEticas)
palavrasAntes = "" * len(PalavrasEticas)
palavrasDepois = "" * len(PalavrasEticas)

ocorrenciasArtigo['PalavrasEticas'] = PalavrasEticas
ocorrenciasArtigo['Ocorrencias'] = linhaInicial
ocorrenciasArtigo["PalavrasAntes"] = palavrasAntes
ocorrenciasArtigo["PalavrasDepois"] = palavrasDepois
ocorrenciasArtigo = ocorrenciasArtigo.set_index('PalavrasEticas')

ocorrenciasArtigo
# Out:
#                      Ocorrencias PalavrasAntes PalavrasDepois
# PalavrasEticas
# autonomy                       0
# beneficence                    0
# bias                           0
# business                       0
# choices                        0
# ...                          ...           ...            ...
# violation                      0
# viability                      0
# visibility                     0
# washing                        0
# working environment            0
#
# [69 rows x 3 columns]

# %%
for i in range(len(textoToK)):
            
        if(textoToK[i] in PalavrasEticas):
            
            ocorrenciasArtigo.loc[textoToK[i], 'Ocorrencias'] += 1
            
            if((i - 1) >= 0):
                if(ocorrenciasArtigo.loc[textoToK[i],'PalavrasAntes'] == ''):
                    ocorrenciasArtigo.loc[textoToK[i], 'PalavrasAntes'] = textoToK[i - 1]
                else:
                    ocorrenciasArtigo.loc[textoToK[i], 'PalavrasAntes'] += ('\n' + textoToK[i - 1])
            if((i + 1) <= (len(textoToK) - 1)):
                if(ocorrenciasArtigo.loc[textoToK[i], 'PalavrasDepois'] == ''):
                    ocorrenciasArtigo.loc[textoToK[i], 'PalavrasDepois'] = textoToK[i + 1]
                else:
                    ocorrenciasArtigo.loc[textoToK[i], 'PalavrasDepois'] += ('\n' + textoToK[i + 1])

ocorrenciasArtigo = ocorrenciasArtigo[ocorrenciasArtigo['Ocorrencias'] > 0]
ocorrenciasArtigo
# Out:
#                 Ocorrencias  \
# PalavrasEticas
# business                  1
# choices                   1
# considerations            1
# deceptive                 4
# exposed                   2
# factors                   2
# forbidden                 7
# framework                98
# harm                      2
# identification            4
# importance                1
# influence                 2
# issues                   13
# knowledge                11
# lack                     11
# legal                     1
# management                4
# negligence                2
# norms                     1
# perspective               1
# practices                 3
# principle                 4
# privacy                   6
# problems                 24
# quality                   9
# requirements             75
# responsible               4
# responsibility            4
# risk                      1
# rules                    13
# skill                     1
# technical                 7
# tool                      2
# toxic                     1
# unpermitted               4
# values                    8
#
#                                                     PalavrasAntes  \
# PalavrasEticas
# business                                                   change
# choices                                                 influence
# considerations                                            ethical
# deceptive                   systems\nrequirements\npurpose\nkinds
# exposed                                               phase\nengi
# factors                                              human\nhuman
# forbidden       practicing\nperforming\nethics\nassociated\nfi...
# framework       ethical\nethical\nproposed\nproposed\nproposed...
# harm                                        ethical\nrequirements
# identification      software\nsoftware\nspecifications\nattention
# importance                                            considering
# influence                                   substantial\nappeared
# issues          management\nethical\nethical\nchannel\nreviewe...
# knowledge       best\nrequirements\nenhance\nidentification\np...
# lack            due\nindustries\nproblems\nrealizing\nautomati...
# legal                                                     ethical
# management                       development\nproject\ngood\nkind
# negligence                                         engineers\ndue
# norms                                                  regulatory
# perspective                                                 first
# practices                                 day\ndeceptive\nethical
# principle                  principles\nprinciple\ncode\nsimilarly
# privacy          data\nsecurity\ncon\nsafety\nprotect\ndentiality
# problems        include\nrelated\ninclude\nrelated\naddresses\...
# quality         ethiopia\nproblems\nperspective\nlack\ntypes\n...
# requirements    software\ngive\nsoftware\nvalues\nsoftware\nco...
# responsible                stakeholders\nengineer\nengineer\nware
# responsibility          professional\nprivacy\nprofessional\nfull
# risk                                                    reduction
# rules           library\nproposed\nideas\nlibrary\nlibrary\nli...
# skill                                                      cycles
# technical       observed\nnon\nproject\nfirstly\nnon\nnon\nenv...
# tool                                            used\npreparation
# toxic                                                    identify
# unpermitted              process\nforbidden\nforbidden\nforbidden
# values          ethical\nsocietal\ntermines\npublic\nethical\n...
#
#                                                    PalavrasDepois
# PalavrasEticas
# business                                             environments
# choices                                                      made
# considerations                                              found
# deceptive       incomplete\nrequirements\nrequirements\npractices
# exposed                                                many\nmany
# factors                                         software\nclients
# forbidden       activities\nactivities\nunpermitted\nunpermitt...
# framework       software\nsoftware\ncomponents\nsuggests\nexpe...
# harm                                            due\nstakeholders
# identification                  knowledge\nclauses\ncon\nanalysis
# importance                                                clauses
# influence                                           choices\nwork
# issues          also\nramingwong\nidentified\naccompanied\ncha...
# knowledge       researchers\ngaps\nengineering\ngaps\nsoftware...
# lack            awareness\nmethods\nintegrated\nproper\nexperi...
# legal                                                  regulatory
# management                 software\nissues\ndiscussion\nproposed
# negligence                                   disregarding\nensure
# norms                                                   standards
# perspective                                               quality
# practices                            place\nduplication\nsoftware
# principle                             principle\ncode\nsays\nsays
# privacy         data\nagreements\nresponsibility\nconfidential...
# problems        associated\nnegative\nquality\nperforming\nide...
# quality         related\nrelated\nrelated\nparticipants\nconce...
# requirements    engineering\npracticing\nhelp\nen\ncourse\neng...
# responsible              stakeholders\ndetect\ndetect\nproceeding
# responsibility                     code\nsoftware\nemployer\nwork
# risk                                                            p
# rules           use\nideas\nused\nuse\nuse\nuse\nuse\nuse\nuse...
# skill                                                    services
# technical       cerns\nstakeholders\nfollowing\ntargeted\npers...
# tool                                                gather\ntaken
# toxic                                                        even
# unpermitted           activities\nclauses\nactivities\nactivities
# values          may\nmay\nartefacts\nsoftware\nrequirements\nr...

# %%
ocorrenciasArtigo = ocorrenciasArtigo.reset_index()

caminhoPasta = 'out'
nomeArquivo = 'Artigo.csv'
caminhoArquivo = os.path.join(caminhoPasta, nomeArquivo)

if not os.path.exists(caminhoPasta):
    os.makedirs(caminhoPasta)

ocorrenciasArtigo.to_csv(caminhoArquivo, sep=',', index=False, header=True, na_rep='N/A', encoding='utf-8')
